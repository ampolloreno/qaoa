# %%
# Out:
# /home/ampolloreno/repos/cotengra/cotengra/hyper.py:29: UserWarning: Couldn't import `kahypar` - skipping from default hyper optimizer and using basic `labels` method instead.
#   warnings.warn("Couldn't import `kahypar` - skipping from default "

# %%
import networkx as nx

reg = 3
n = 20
seed = 666
G = nx.random_regular_graph(reg, n, seed=seed)

terms = {(i, j): 1 for i, j in G.edges}

# %%
p = 1
gammas = qu.randn(p)
betas = qu.randn(p)
circ_ex = qtn.circuit_gen.circ_qaoa(terms, p, gammas, betas)
tm = circ_ex.to_dense_tn()
circ_ex.update_params_from(tm)

# %%
circ_ex.psi.draw(color=['PSI0', 'H', 'RZZ', 'RX'])

# %%
circ_ex.get_rdm_lightcone_simplified([0]).draw(color=['PSI0', 'H', 'RZZ', 'RX'], highlight_inds=['k0', 'b0'])

# %%
import tqdm

# ZZ = qu.pauli('Z') & qu.pauli('Z')

# local_exp_rehs = [
#     circ_ex.sample_rehearse(weight * ZZ, edge, optimize=opt)
#     for edge, weight in tqdm.tqdm(list(terms.items()))
# ]

circ_ex.sample_rehearse();

# %%
list(circ_ex.sample(1))
# Out:
# ['01110101010010110010']

# %%
p = 1
gammas = qu.randn(p)
betas = qu.randn(p)
circ_ex2 = qtn.circuit_gen.circ_qaoa(terms, p, gammas, betas)
tm = circ_ex2.to_dense_tn()
circ_ex.update_params_from(tm)

# %%
list(circ_ex.sample(1))
# Out:
# ['10100001011001000101']
