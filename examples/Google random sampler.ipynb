# %%
from recirq.optimize.mgd import _random_point_in_ball

# %%
n = 100000
points = [_random_point_in_ball(2, 1) for _ in range(n)]

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams["figure.figsize"] = (5,5) # (w, h)
plt.scatter(np.array(points).T[0], np.array(points).T[1], s=.01)
plt.tight_layout()
